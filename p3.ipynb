# %% [markdown]
# # 0. Libraries

# %%
import numpy as np
import pandas as pd
from Bio import Entrez
import xml.etree.ElementTree as ET
import os
import re
from datetime import datetime
from typing import List, Dict, Optional, Tuple
import requests
from urllib.parse import urljoin, urlparse
import time
import json

# %% [markdown]
# # 5. Download html of articles

# %%
import os
import time
import random
import requests
import pandas as pd
from bs4 import BeautifulSoup

def get_html_from_pmc(pmc_id: str) -> BeautifulSoup:
    """Descarga y devuelve el contenido HTML del artículo de PubMed Central (PMC),
    con headers y una pausa aleatoria para evitar bloqueos."""
    
    url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc_id}/"

    headers = {
        "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
                      "(KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
    }

    try:
        response = requests.get(url, headers=headers, timeout=15)

        # Pausa entre 1 y 3 segundos para evitar bloqueo
        time.sleep(random.uniform(1, 3))

        if response.status_code == 200:
            return BeautifulSoup(response.text, "html.parser")
        else:
            print(f"⚠️ Error {response.status_code} al descargar {pmc_id}")
            return None

    except requests.exceptions.RequestException as e:
        print(f"❌ Error al conectar con {pmc_id}: {e}")
        return None

def download_html_from_csv(csv_file: str, output_folder: str = "pmc_htmls", 
                          skip_existing: bool = True, max_retries: int = 3) -> None:
    """Descarga los archivos HTML de todos los artículos del CSV y los guarda localmente.
    
    Args:
        csv_file: Ruta al archivo CSV con los PMC_ID
        output_folder: Carpeta donde guardar los HTML
        skip_existing: Si True, omite archivos ya descargados
        max_retries: Número máximo de reintentos por archivo
    """
    df = pd.read_csv(csv_file)

    # Crear carpeta si no existe
    os.makedirs(output_folder, exist_ok=True)

    # Contadores para estadísticas
    downloaded = 0
    skipped = 0
    failed = 0

    for index, row in df.iterrows():
        pmc_id = row["PMC_ID"]
        file_path = os.path.join(output_folder, f"{pmc_id}.html")
        
        # Verificar si el archivo ya existe
        if skip_existing and os.path.exists(file_path):
            print(f"⏭️  Saltando {pmc_id} (ya existe)")
            skipped += 1
            continue
        
        print(f"📥 Descargando {pmc_id} ({index + 1}/{len(df)}) ...")
        
        url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc_id}/"
        headers = {
            "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
                          "(KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
        }

        # Intentar descarga con reintentos
        success = False
        for attempt in range(max_retries):
            try:
                response = requests.get(url, headers=headers, timeout=15)

                # Pausa entre 1 y 3 segundos para evitar bloqueo
                time.sleep(random.uniform(1, 3))

                if response.status_code == 200:
                    with open(file_path, "w", encoding="utf-8") as f:
                        f.write(response.text)
                    print(f"✅ Guardado en {file_path}")
                    downloaded += 1
                    success = True
                    break
                else:
                    print(f"⚠️ Error {response.status_code} al descargar {pmc_id} (intento {attempt + 1}/{max_retries})")
                    
                    # Pausa más larga en caso de error
                    time.sleep(random.uniform(2, 5))

            except requests.exceptions.RequestException as e:
                print(f"❌ Error al conectar con {pmc_id} (intento {attempt + 1}/{max_retries}): {e}")
                # Pausa más larga en caso de error de conexión
                time.sleep(random.uniform(3, 7))
        
        if not success:
            print(f"💥 Falló la descarga de {pmc_id} después de {max_retries} intentos")
            failed += 1

    # Mostrar resumen
    print(f"\n🎉 Descarga completada:")
    print(f"   ✅ Descargados: {downloaded}")
    print(f"   ⏭️  Saltados: {skipped}")
    print(f"   💥 Fallados: {failed}")
    print(f"   📊 Total procesados: {downloaded + skipped + failed}")

def check_download_status(csv_file: str, output_folder: str = "pmc_htmls") -> None:
    """Verifica el estado de descarga de los archivos."""
    df = pd.read_csv(csv_file)
    
    downloaded = 0
    missing = []
    
    for _, row in df.iterrows():
        pmc_id = row["PMC_ID"]
        file_path = os.path.join(output_folder, f"{pmc_id}.html")
        
        if os.path.exists(file_path):
            downloaded += 1
        else:
            missing.append(pmc_id)
    
    print(f"\n📊 Estado de descargas:")
    print(f"   ✅ Descargados: {downloaded}/{len(df)}")
    print(f"   ❌ Faltantes: {len(missing)}")
    
    if missing:
        print(f"   📋 IDs faltantes: {missing}")

# %% [markdown]
# # 6. Add the others columns to csv with
# df = pd.read_csv("articles_with_pmcid.csv")

# %% [markdown]
# # 4. Main

# %%
if __name__ == "__main__":
    csv_file = "articles_with_pmcid.csv"
    output_folder = "pmc_htmls"
    
    # Verificar estado actual
    check_download_status(csv_file, output_folder)
    
    print("\nPuedes elegir continuar con la descarga o cancelar.")

    # Preguntar al usuario qué hacer
    response = input("\n¿Quieres continuar con la descarga? (s/n): ")
    if response.lower() in ['s', 'si', 'sí', 'y', 'yes']:
        download_html_from_csv(csv_file, output_folder, skip_existing=True)
    else:
        print("Descarga cancelada.")
# Out:
# 📊 Estado de descargas:
#    ✅ Descargados: 607/607
#    ❌ Faltantes: 0
#
# Puedes elegir continuar con la descarga o cancelar.
# ⏭️  Saltando PMC4136787 (ya existe)
# ⏭️  Saltando PMC3630201 (ya existe)
# ⏭️  Saltando PMC11988870 (ya existe)
# ⏭️  Saltando PMC7998608 (ya existe)
# ⏭️  Saltando PMC5587110 (ya existe)
# ⏭️  Saltando PMC8396460 (ya existe)
# ⏭️  Saltando PMC5666799 (ya existe)
# ⏭️  Saltando PMC5460236 (ya existe)
# ⏭️  Saltando PMC6222041 (ya existe)
# ⏭️  Saltando PMC6813909 (ya existe)
# ⏭️  Saltando PMC4095884 (ya existe)
# ⏭️  Saltando PMC3040128 (ya existe)
# ⏭️  Saltando PMC3177255 (ya existe)
# ⏭️  Saltando PMC11500582 (ya existe)
# ⏭️  Saltando PMC5387210 (ya existe)
# ⏭️  Saltando PMC4642138 (ya existe)
# ⏭️  Saltando PMC5387210 (ya existe)
# ⏭️  Saltando PMC2915878 (ya existe)
# ⏭️  Saltando PMC3901686 (ya existe)
# ⏭️  Saltando PMC6985101 (ya existe)
# ⏭️  Saltando PMC6387434 (ya existe)
# ⏭️  Saltando PMC6371294 (ya existe)
# ⏭️  Saltando PMC7072278 (ya existe)
# ⏭️  Saltando PMC8441986 (ya existe)
# ⏭️  Saltando PMC9400218 (ya existe)
# ⏭️  Saltando PMC9267413 (ya existe)
# ⏭️  Saltando PMC9576569 (ya existe)
# ⏭️  Saltando PMC10789781 (ya existe)
# ⏭️  Saltando PMC10772081 (ya existe)
# ⏭️  Saltando PMC11166946 (ya existe)
# ⏭️  Saltando PMC11166944 (ya existe)
# ⏭️  Saltando PMC11166968 (ya existe)
# ⏭️  Saltando PMC7000411 (ya existe)
# ⏭️  Saltando PMC7787258 (ya existe)
# ⏭️  Saltando PMC8716943 (ya existe)
# ⏭️  Saltando PMC4826010 (ya existe)
# ⏭️  Saltando PMC6048781 (ya existe)
# ⏭️  Saltando PMC7010715 (ya existe)
# ⏭️  Saltando PMC7503278 (ya existe)
# ⏭️  Saltando PMC8364238 (ya existe)
# ⏭️  Saltando PMC11579474 (ya existe)
# ⏭️  Saltando PMC2998437 (ya existe)
# ⏭️  Saltando PMC3005423 (ya existe)
# ⏭️  Saltando PMC3190158 (ya existe)
# ⏭️  Saltando PMC3289768 (ya existe)
# ⏭️  Saltando PMC3508904 (ya existe)
# ⏭️  Saltando PMC3430326 (ya existe)
# ⏭️  Saltando PMC3593973 (ya existe)
# ⏭️  Saltando PMC5018776 (ya existe)
# ⏭️  Saltando PMC4896697 (ya existe)
# ⏭️  Saltando PMC11127935 (ya existe)
# ⏭️  Saltando PMC11831363 (ya existe)
# ⏭️  Saltando PMC11930778 (ya existe)
# ⏭️  Saltando PMC8816950 (ya existe)
# ⏭️  Saltando PMC3774184 (ya existe)
# ⏭️  Saltando PMC4118556 (ya existe)
# ⏭️  Saltando PMC4653813 (ya existe)
# ⏭️  Saltando PMC6915713 (ya existe)
# ⏭️  Saltando PMC6124165 (ya existe)
# ⏭️  Saltando PMC8509868 (ya existe)
# ⏭️  Saltando PMC11063234 (ya existe)
# ⏭️  Saltando PMC5672023 (ya existe)
# ⏭️  Saltando PMC5899691 (ya existe)
# ⏭️  Saltando PMC6204554 (ya existe)
# ⏭️  Saltando PMC4064004 (ya existe)
# ⏭️  Saltando PMC3818365 (ya existe)
# ⏭️  Saltando PMC3981873 (ya existe)
# ⏭️  Saltando PMC4150462 (ya existe)
# ⏭️  Saltando PMC4378170 (ya existe)
# ⏭️  Saltando PMC4618186 (ya existe)
# ⏭️  Saltando PMC4453782 (ya existe)
# ⏭️  Saltando PMC4902601 (ya existe)
# ⏭️  Saltando PMC4776492 (ya existe)
# ⏭️  Saltando PMC5415411 (ya existe)
# ⏭️  Saltando PMC6289879 (ya existe)
# ⏭️  Saltando PMC7987364 (ya existe)
# ⏭️  Saltando PMC8099722 (ya existe)
# ⏭️  Saltando PMC5116466 (ya existe)
# ⏭️  Saltando PMC4033213 (ya existe)
# ⏭️  Saltando PMC6081456 (ya existe)
# ⏭️  Saltando PMC5955502 (ya existe)
# ⏭️  Saltando PMC10285634 (ya existe)
# ⏭️  Saltando PMC11271499 (ya existe)
# ⏭️  Saltando PMC6062551 (ya existe)
# ⏭️  Saltando PMC9832585 (ya existe)
# ⏭️  Saltando PMC7829349 (ya existe)
# ⏭️  Saltando PMC3570223 (ya existe)
# ⏭️  Saltando PMC3457586 (ya existe)
# ⏭️  Saltando PMC3558598 (ya existe)
# ⏭️  Saltando PMC11046949 (ya existe)
# ⏭️  Saltando PMC3890248 (ya existe)
# ⏭️  Saltando PMC3868799 (ya existe)
# ⏭️  Saltando PMC4960141 (ya existe)
# ⏭️  Saltando PMC5736159 (ya existe)
# ⏭️  Saltando PMC5761896 (ya existe)
# ⏭️  Saltando PMC5826609 (ya existe)
# ⏭️  Saltando PMC6366624 (ya existe)
# ⏭️  Saltando PMC11929063 (ya existe)
# ⏭️  Saltando PMC11929063 (ya existe)
# ⏭️  Saltando PMC10996920 (ya existe)
# ⏭️  Saltando PMC7954810 (ya existe)
# ⏭️  Saltando PMC4228280 (ya existe)
# ⏭️  Saltando PMC3639165 (ya existe)
# ⏭️  Saltando PMC8044432 (ya existe)
# ⏭️  Saltando PMC7778922 (ya existe)
# ⏭️  Saltando PMC7870178 (ya existe)
# ⏭️  Saltando PMC7733874 (ya existe)
# ⏭️  Saltando PMC7828077 (ya existe)
# ⏭️  Saltando PMC8044432 (ya existe)
# ⏭️  Saltando PMC11166911 (ya existe)
# ⏭️  Saltando PMC11167097 (ya existe)
# ⏭️  Saltando PMC11094041 (ya existe)
# ⏭️  Saltando PMC11053165 (ya existe)
# ⏭️  Saltando PMC11403809 (ya existe)
# ⏭️  Saltando PMC8513672 (ya existe)
# ⏭️  Saltando PMC11126634 (ya existe)
# ⏭️  Saltando PMC11386075 (ya existe)
# ⏭️  Saltando PMC3502426 (ya existe)
# ⏭️  Saltando PMC3856860 (ya existe)
# ⏭️  Saltando PMC3615599 (ya existe)
# ⏭️  Saltando PMC4050424 (ya existe)
# ⏭️  Saltando PMC3659353 (ya existe)
# ⏭️  Saltando PMC4169763 (ya existe)
# ⏭️  Saltando PMC4398884 (ya existe)
# ⏭️  Saltando PMC4379453 (ya existe)
# ⏭️  Saltando PMC4385880 (ya existe)
# ⏭️  Saltando PMC4964660 (ya existe)
# ⏭️  Saltando PMC5866446 (ya existe)
# ⏭️  Saltando PMC6165321 (ya existe)
# ⏭️  Saltando PMC7339929 (ya existe)
# ⏭️  Saltando PMC8220224 (ya existe)
# ⏭️  Saltando PMC2910419 (ya existe)
# ⏭️  Saltando PMC3166430 (ya existe)
# ⏭️  Saltando PMC6615562 (ya existe)
# ⏭️  Saltando PMC7324008 (ya existe)
# ⏭️  Saltando PMC8412175 (ya existe)
# ⏭️  Saltando PMC10607959 (ya existe)
# ⏭️  Saltando PMC9699585 (ya existe)
# ⏭️  Saltando PMC9953055 (ya existe)
# ⏭️  Saltando PMC10528075 (ya existe)
# ⏭️  Saltando PMC10813126 (ya existe)
# ⏭️  Saltando PMC10390562 (ya existe)
# ⏭️  Saltando PMC4290804 (ya existe)
# ⏭️  Saltando PMC5515520 (ya existe)
# ⏭️  Saltando PMC5286820 (ya existe)
# ⏭️  Saltando PMC5470433 (ya existe)
# ⏭️  Saltando PMC5491145 (ya existe)
# ⏭️  Saltando PMC5996828 (ya existe)
# ⏭️  Saltando PMC6201722 (ya existe)
# ⏭️  Saltando PMC6240453 (ya existe)
# ⏭️  Saltando PMC6447593 (ya existe)
# ⏭️  Saltando PMC7264257 (ya existe)
# ⏭️  Saltando PMC7064724 (ya existe)
# ⏭️  Saltando PMC6379395 (ya existe)
# ⏭️  Saltando PMC4187166 (ya existe)
# ⏭️  Saltando PMC5219934 (ya existe)
# ⏭️  Saltando PMC6386654 (ya existe)
# ⏭️  Saltando PMC7940393 (ya existe)
# ⏭️  Saltando PMC9023564 (ya existe)
# ⏭️  Saltando PMC9389742 (ya existe)
# ⏭️  Saltando PMC2824534 (ya existe)
# ⏭️  Saltando PMC2991213 (ya existe)
# ⏭️  Saltando PMC8269219 (ya existe)
# ⏭️  Saltando PMC11362537 (ya existe)
# ⏭️  Saltando PMC9111996 (ya existe)
# ⏭️  Saltando PMC10308117 (ya existe)
# ⏭️  Saltando PMC10233975 (ya existe)
# ⏭️  Saltando PMC10848226 (ya existe)
# ⏭️  Saltando PMC3329368 (ya existe)
# ⏭️  Saltando PMC12008199 (ya existe)
# ⏭️  Saltando PMC12008199 (ya existe)
# ⏭️  Saltando PMC4035928 (ya existe)
# ⏭️  Saltando PMC12008199 (ya existe)
# ⏭️  Saltando PMC5181587 (ya existe)
# ⏭️  Saltando PMC4936552 (ya existe)
# ⏭️  Saltando PMC7610290 (ya existe)
# ⏭️  Saltando PMC5614317 (ya existe)
# ⏭️  Saltando PMC5677518 (ya existe)
# ⏭️  Saltando PMC11850895 (ya existe)
# ⏭️  Saltando PMC7076552 (ya existe)
# ⏭️  Saltando PMC7414185 (ya existe)
# ⏭️  Saltando PMC8133610 (ya existe)
# ⏭️  Saltando PMC8113475 (ya existe)
# ⏭️  Saltando PMC9706465 (ya existe)
# ⏭️  Saltando PMC10027818 (ya existe)
# ⏭️  Saltando PMC3337602 (ya existe)
# ⏭️  Saltando PMC4490751 (ya existe)
# ⏭️  Saltando PMC5132293 (ya existe)
# ⏭️  Saltando PMC11747068 (ya existe)
# ⏭️  Saltando PMC5666834 (ya existe)
# ⏭️  Saltando PMC6753329 (ya existe)
# ⏭️  Saltando PMC7012842 (ya existe)
# ⏭️  Saltando PMC4405755 (ya existe)
# ⏭️  Saltando PMC8260663 (ya existe)
# ⏭️  Saltando PMC4647464 (ya existe)
# ⏭️  Saltando PMC5659752 (ya existe)
# ⏭️  Saltando PMC6372189 (ya existe)
# ⏭️  Saltando PMC6945029 (ya existe)
# ⏭️  Saltando PMC7000411 (ya existe)
# ⏭️  Saltando PMC8191917 (ya existe)
# ⏭️  Saltando PMC9865768 (ya existe)
# ⏭️  Saltando PMC10797188 (ya existe)
# ⏭️  Saltando PMC10797188 (ya existe)
# ⏭️  Saltando PMC7555395 (ya existe)
# ⏭️  Saltando PMC4309212 (ya existe)
# ⏭️  Saltando PMC6560652 (ya existe)
# ⏭️  Saltando PMC6321533 (ya existe)
# ⏭️  Saltando PMC12040010 (ya existe)
# ⏭️  Saltando PMC11833055 (ya existe)
# ⏭️  Saltando PMC9146534 (ya existe)
# ⏭️  Saltando PMC11492218 (ya existe)
# ⏭️  Saltando PMC7055474 (ya existe)
# ⏭️  Saltando PMC7118179 (ya existe)
# ⏭️  Saltando PMC4494396 (ya existe)
# ⏭️  Saltando PMC8323809 (ya existe)
# ⏭️  Saltando PMC8886715 (ya existe)
# ⏭️  Saltando PMC8890767 (ya existe)
# ⏭️  Saltando PMC9487896 (ya existe)
# ⏭️  Saltando PMC10142442 (ya existe)
# ⏭️  Saltando PMC11477029 (ya existe)
# ⏭️  Saltando PMC4309301 (ya existe)
# ⏭️  Saltando PMC11166981 (ya existe)
# ⏭️  Saltando PMC6343501 (ya existe)
# ⏭️  Saltando PMC7138367 (ya existe)
# ⏭️  Saltando PMC6689164 (ya existe)
# ⏭️  Saltando PMC3564669 (ya existe)
# ⏭️  Saltando PMC4042434 (ya existe)
# ⏭️  Saltando PMC4161659 (ya existe)
# ⏭️  Saltando PMC4917201 (ya existe)
# ⏭️  Saltando PMC4985531 (ya existe)
# ⏭️  Saltando PMC5421618 (ya existe)
# ⏭️  Saltando PMC5515514 (ya existe)
# ⏭️  Saltando PMC8671758 (ya existe)
# ⏭️  Saltando PMC5771473 (ya existe)
# ⏭️  Saltando PMC5288125 (ya existe)
# ⏭️  Saltando PMC5389344 (ya existe)
# ⏭️  Saltando PMC9784906 (ya existe)
# ⏭️  Saltando PMC6548323 (ya existe)
# ⏭️  Saltando PMC6597714 (ya existe)
# ⏭️  Saltando PMC6865368 (ya existe)
# ⏭️  Saltando PMC7907224 (ya existe)
# ⏭️  Saltando PMC8213760 (ya existe)
# ⏭️  Saltando PMC9582271 (ya existe)
# ⏭️  Saltando PMC10063413 (ya existe)
# ⏭️  Saltando PMC10889206 (ya existe)
# ⏭️  Saltando PMC8468678 (ya existe)
# ⏭️  Saltando PMC9031868 (ya existe)
# ⏭️  Saltando PMC10030976 (ya existe)
# ⏭️  Saltando PMC5910807 (ya existe)
# ⏭️  Saltando PMC12021249 (ya existe)
# ⏭️  Saltando PMC6057834 (ya existe)
# ⏭️  Saltando PMC6876156 (ya existe)
# ⏭️  Saltando PMC7415877 (ya existe)
# ⏭️  Saltando PMC7285199 (ya existe)
# ⏭️  Saltando PMC9549344 (ya existe)
# ⏭️  Saltando PMC7530743 (ya existe)
# ⏭️  Saltando PMC7890410 (ya existe)
# ⏭️  Saltando PMC9640571 (ya existe)
# ⏭️  Saltando PMC9862956 (ya existe)
# ⏭️  Saltando PMC10410709 (ya existe)
# ⏭️  Saltando PMC10751425 (ya existe)
# ⏭️  Saltando PMC10605753 (ya existe)
# ⏭️  Saltando PMC10846184 (ya existe)
# ⏭️  Saltando PMC11166967 (ya existe)
# ⏭️  Saltando PMC11302229 (ya existe)
# ⏭️  Saltando PMC11487192 (ya existe)
# ⏭️  Saltando PMC3554398 (ya existe)
# ⏭️  Saltando PMC10370681 (ya existe)
# ⏭️  Saltando PMC4624184 (ya existe)
# ⏭️  Saltando PMC4945788 (ya existe)
# ⏭️  Saltando PMC9116463 (ya existe)
# ⏭️  Saltando PMC5201052 (ya existe)
# ⏭️  Saltando PMC5391430 (ya existe)
# ⏭️  Saltando PMC5504618 (ya existe)
# ⏭️  Saltando PMC5580210 (ya existe)
# ⏭️  Saltando PMC8421509 (ya existe)
# ⏭️  Saltando PMC5552977 (ya existe)
# ⏭️  Saltando PMC5805884 (ya existe)
# ⏭️  Saltando PMC5864415 (ya existe)
# ⏭️  Saltando PMC6013642 (ya existe)
# ⏭️  Saltando PMC5578834 (ya existe)
# ⏭️  Saltando PMC9241228 (ya existe)
# ⏭️  Saltando PMC5958250 (ya existe)
# ⏭️  Saltando PMC7326050 (ya existe)
# ⏭️  Saltando PMC6251167 (ya existe)
# ⏭️  Saltando PMC6280456 (ya existe)
# ⏭️  Saltando PMC9098231 (ya existe)
# ⏭️  Saltando PMC9116463 (ya existe)
# ⏭️  Saltando PMC6426649 (ya existe)
# ⏭️  Saltando PMC6452512 (ya existe)
# ⏭️  Saltando PMC6529585 (ya existe)
# ⏭️  Saltando PMC6952069 (ya existe)
# ⏭️  Saltando PMC7303416 (ya existe)
# ⏭️  Saltando PMC7317102 (ya existe)
# ⏭️  Saltando PMC7393961 (ya existe)
# ⏭️  Saltando PMC7484075 (ya existe)
# ⏭️  Saltando PMC7516158 (ya existe)
# ⏭️  Saltando PMC7561690 (ya existe)
# ⏭️  Saltando PMC7595942 (ya existe)
# ⏭️  Saltando PMC7677455 (ya existe)
# ⏭️  Saltando PMC8005752 (ya existe)
# ⏭️  Saltando PMC8104057 (ya existe)
# ⏭️  Saltando PMC12034939 (ya existe)
# ⏭️  Saltando PMC8012687 (ya existe)
# ⏭️  Saltando PMC8086211 (ya existe)
# ⏭️  Saltando PMC8211661 (ya existe)
# ⏭️  Saltando PMC11988970 (ya existe)
# ⏭️  Saltando PMC8754149 (ya existe)
# ⏭️  Saltando PMC8875396 (ya existe)
# ⏭️  Saltando PMC9258157 (ya existe)
# ⏭️  Saltando PMC9503880 (ya existe)
# ⏭️  Saltando PMC9743659 (ya existe)
# ⏭️  Saltando PMC10233975 (ya existe)
# ⏭️  Saltando PMC10308117 (ya existe)
# ⏭️  Saltando PMC10715203 (ya existe)
# ⏭️  Saltando PMC10628120 (ya existe)
# ⏭️  Saltando PMC10960378 (ya existe)
# ⏭️  Saltando PMC10628120 (ya existe)
# ⏭️  Saltando PMC11451251 (ya existe)
# ⏭️  Saltando PMC5523082 (ya existe)
# ⏭️  Saltando PMC6590338 (ya existe)
# ⏭️  Saltando PMC6036641 (ya existe)
# ⏭️  Saltando PMC6599637 (ya existe)
# ⏭️  Saltando PMC8274610 (ya existe)
# ⏭️  Saltando PMC8131644 (ya existe)
# ⏭️  Saltando PMC9163032 (ya existe)
# ⏭️  Saltando PMC5568470 (ya existe)
# ⏭️  Saltando PMC5485990 (ya existe)
# ⏭️  Saltando PMC5460239 (ya existe)
# ⏭️  Saltando PMC6275019 (ya existe)
# ⏭️  Saltando PMC5397022 (ya existe)
# ⏭️  Saltando PMC7251690 (ya existe)
# ⏭️  Saltando PMC10284894 (ya existe)
# ⏭️  Saltando PMC10030976 (ya existe)
# ⏭️  Saltando PMC8421509 (ya existe)
# ⏭️  Saltando PMC9964234 (ya existe)
# ⏭️  Saltando PMC10793275 (ya existe)
# ⏭️  Saltando PMC4116675 (ya existe)
# ⏭️  Saltando PMC5810432 (ya existe)
# ⏭️  Saltando PMC10261121 (ya existe)
# ⏭️  Saltando PMC8739323 (ya existe)
# ⏭️  Saltando PMC8739323 (ya existe)
# ⏭️  Saltando PMC9502502 (ya existe)
# ⏭️  Saltando PMC10432549 (ya existe)
# ⏭️  Saltando PMC7261848 (ya existe)
# ⏭️  Saltando PMC8537831 (ya existe)
# ⏭️  Saltando PMC8879990 (ya existe)
# ⏭️  Saltando PMC10472590 (ya existe)
# ⏭️  Saltando PMC11999716 (ya existe)
# ⏭️  Saltando PMC11969330 (ya existe)
# ⏭️  Saltando PMC11940681 (ya existe)
# ⏭️  Saltando PMC11941215 (ya existe)
# ⏭️  Saltando PMC11892206 (ya existe)
# ⏭️  Saltando PMC11748630 (ya existe)
# ⏭️  Saltando PMC11659408 (ya existe)
# ⏭️  Saltando PMC11701653 (ya existe)
# ⏭️  Saltando PMC11593819 (ya existe)
# ⏭️  Saltando PMC11477029 (ya existe)
# ⏭️  Saltando PMC11487192 (ya existe)
# ⏭️  Saltando PMC11484870 (ya existe)
# ⏭️  Saltando PMC11451251 (ya existe)
# ⏭️  Saltando PMC11403809 (ya existe)
# ⏭️  Saltando PMC11386075 (ya existe)
# ⏭️  Saltando PMC11362537 (ya existe)
# ⏭️  Saltando PMC11339457 (ya existe)
# ⏭️  Saltando PMC11324864 (ya existe)
# ⏭️  Saltando PMC11353732 (ya existe)
# ⏭️  Saltando PMC11271499 (ya existe)
#
# 🎉 Descarga completada:
#    ✅ Descargados: 0
#    ⏭️  Saltados: 607
#    💥 Fallados: 0
#    📊 Total procesados: 607

# %%
def extract_pmc_id(url_or_id):
    """Extrae el PMC ID de una URL o devuelve el ID si ya está limpio"""
    if isinstance(url_or_id, str):
        if 'PMC' in url_or_id:
            # Buscar patrón PMC seguido de números
            match = re.search(r'PMC\d+', url_or_id)
            if match:
                return match.group()
    return url_or_id

def get_article_xml(pmc_id):
    """Descarga el XML del artículo desde PMC"""
    try:
        # URL de la API de PMC para obtener el XML
        url = f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pmc_id}/?tool=python_script&email=researcher@example.com"
        
        # También intentamos con la API de efetch
        efetch_url = f"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pmc&id={pmc_id.replace('PMC', '')}&rettype=xml"
        
        response = requests.get(efetch_url, timeout=30)
        response.raise_for_status()
        
        return response.text
    except Exception as e:
        print(f"Error descargando {pmc_id}: {e}")
        return None

def extract_authors(root):
    """Extrae los autores del XML"""
    authors = []
    
    # Buscar autores en diferentes ubicaciones del XML
    for contrib in root.findall(".//contrib[@contrib-type='author']"):
        author_parts = []
        
        # Nombre
        given_names = contrib.find(".//given-names")
        if given_names is not None:
            author_parts.append(given_names.text)
        
        # Apellido
        surname = contrib.find(".//surname")
        if surname is not None:
            author_parts.append(surname.text)
        
        if author_parts:
            authors.append(" ".join(author_parts))
    
    return "; ".join(authors) if authors else "N/A"

def extract_keywords(root):
    """Extrae las palabras clave del XML"""
    keywords = []
    
    # Buscar keywords en diferentes ubicaciones
    for kwd in root.findall(".//kwd"):
        if kwd.text:
            keywords.append(kwd.text.strip())
    
    return "; ".join(keywords) if keywords else "N/A"

def extract_references_count(root):
    """Cuenta las referencias del artículo"""
    refs = root.findall(".//ref")
    return len(refs)

def extract_abstract(root):
    """Extrae el abstract del XML"""
    abstract_parts = []
    
    # Buscar abstract
    abstract_elem = root.find(".//abstract")
    if abstract_elem is not None:
        # Obtener todo el texto del abstract
        for p in abstract_elem.findall(".//p"):
            if p.text:
                abstract_parts.append(p.text.strip())
    
    abstract_text = " ".join(abstract_parts) if abstract_parts else "N/A"
    
    # Limpiar el texto
    abstract_text = re.sub(r'\s+', ' ', abstract_text).strip()
    return abstract_text

def extract_publication_info(root):
    """Extrae información de publicación"""
    # Año
    year = "N/A"
    pub_date = root.find(".//pub-date[@pub-type='epub']") or root.find(".//pub-date[@pub-type='ppub']") or root.find(".//pub-date")
    if pub_date is not None:
        year_elem = pub_date.find(".//year")
        if year_elem is not None:
            year = year_elem.text
    
    # Tipo de publicación
    article_type = "N/A"
    article_elem = root.find(".//article[@article-type]")
    if article_elem is not None:
        article_type = article_elem.get('article-type', 'N/A')
    
    return year, article_type

def process_csv_file(input_file):
    """Procesa el archivo CSV y extrae los datos de cada artículo"""
    
    # Leer el CSV
    try:
        df = pd.read_csv(input_file)
        print(f"Archivo CSV cargado con {len(df)} filas")
    except Exception as e:
        print(f"Error leyendo el CSV: {e}")
        return
    
    # Preparar lista para los resultados
    results = []
    
    # Procesar cada fila
    for idx, row in df.iterrows():
        print(f"Procesando artículo {idx + 1}/{len(df)}...")
        
        # Extraer PMC ID
        pmc_id = extract_pmc_id(row.get('PMC_ID', ''))
        if not pmc_id or not pmc_id.startswith('PMC'):
            print(f"PMC ID inválido en fila {idx}: {pmc_id}")
            continue
        
        # Descargar XML
        xml_content = get_article_xml(pmc_id)
        if not xml_content:
            print(f"No se pudo descargar XML para {pmc_id}")
            continue
        
        try:
            # Parsear XML
            root = ET.fromstring(xml_content)
            
            # Extraer título
            title_elem = root.find(".//title-group/article-title") or root.find(".//article-title")
            title = title_elem.text if title_elem is not None else row.get('Title', 'N/A')
            
            # Extraer datos
            authors = extract_authors(root)
            keywords = extract_keywords(root)
            references = extract_references_count(root)
            abstract = extract_abstract(root)
            year, pub_type = extract_publication_info(root)
            
            # URL original
            url = row.get('Link', 'N/A')
            
            # Agregar a resultados
            results.append({
                'PMC_ID': pmc_id,
                'Title': title,
                'Authors': authors,
                'Keywords': keywords,
                'References_Count': references,
                'Abstract': abstract,
                'Year': year,
                'Publication_Type': pub_type,
                'URL': url
            })
            
            print(f"✓ Procesado exitosamente: {pmc_id}")
            
        except ET.ParseError as e:
            print(f"Error parseando XML para {pmc_id}: {e}")
        except Exception as e:
            print(f"Error procesando {pmc_id}: {e}")
        
        # Pausa para no sobrecargar el servidor
        time.sleep(1)
    
    # Guardar resultados
    if results:
        output_df = pd.DataFrame(results)
        output_df.to_csv('result2', index=False, encoding='utf-8')
        print(f"\n✓ Archivo guardado: result2.csv ({len(results)} artículos procesados)")
        
        # Mostrar resumen
        print("\nResumen de datos extraídos:")
        print(f"- Artículos procesados: {len(results)}")
        print(f"- Con autores: {sum(1 for r in results if r['Authors'] != 'N/A')}")
        print(f"- Con keywords: {sum(1 for r in results if r['Keywords'] != 'N/A')}")
        print(f"- Con abstract: {sum(1 for r in results if r['Abstract'] != 'N/A')}")
    else:
        print("No se pudieron procesar artículos.")

# Función principal
def main():
    input_file = "articles_with_pmcid.csv"  # Cambia esto por el nombre de tu archivo
    
    print("=== Extractor de Datos de Artículos PMC ===")
    print(f"Procesando archivo: {input_file}")
    print("Esto puede tomar varios minutos dependiendo del número de artículos...\n")
    
    process_csv_file(input_file)

# %%
#if __name__ == "__main__":
#    main()

# %%
dfr = pd.read_csv("articles_data.csv")
dfr.head()
# Out:
#         PMC_ID  Title Authors  \
# 0   PMC4136787    NaN      []
# 1   PMC3630201    NaN      []
# 2  PMC11988870    NaN      []
# 3   PMC7998608    NaN      []
# 4   PMC5587110    NaN      []
#
#                                         Introduction  \
# 0  After a 16-year hiatus, Russia resumed in 2013...
# 1  On Earth, at 1 g, mechanical loading of mammal...
# 2  Microgravity, a condition characterized by min...
# 3  Human adipose-derived stem cells (hASCs) are e...
# 4  The ISS National Laboratory is a unique resear...
#
#                                  Development/Methods  \
# 0  The study was approved by IACUC of MSU Institu...
# 1  All experimental animal procedures for STS-131...
# 2  A comprehensive literature review was conducte...
# 3  Human lipoaspirates were obtained from 12 heal...
# 4  In order to validate the system, a number of g...
#
#                                              Results  \
# 0  Living conditions for animals considered optim...
# 1  All flight and ground control mice were observ...
# 2                                                NaN
# 3  Cells were expanded for three passages before ...
# 4  In order to assess the functionality of PCR in...
#
#                                           Discussion References
# 0  Living conditions for animals considered optim...         []
# 1  In this study, we investigated cellular and mo...         []
# 2  Recent research demonstrates that microgravity...         []
# 3  Through novel advances in cell biology, adult ...         []
# 4  One of the major obstacles to space exploratio...         []

# %%
dfr2 = pd.read_csv("result2")
dfr2.head()
# Out:
#         PMC_ID                                              Title  \
# 0   PMC4136787  Mice in Bion-M 1 Space Mission: Training and S...
# 1   PMC3630201  Microgravity Induces Pelvic Bone Loss through ...
# 2  PMC11988870  Microgravity and Cellular Biology: Insights in...
# 3   PMC7998608  Selective Proliferation of Highly Functional A...
# 4   PMC5587110  Microgravity validation of a novel system for ...
#
#                                              Authors  \
# 0  Alexander Andreev-Andrievskiy; Anfisa Popova; ...
# 1  Elizabeth A. Blaber; Natalya Dvorochkin; Chial...
# 2  Nelson Adolfo López Garzón; María Virginia Pin...
# 3  Takanobu Mashiko; Koji Kanayama; Natsumi Saito...
# 4  Macarena Parra; Jimmy Jung; Travis D. Boone; L...
#
#                                             Keywords  References_Count  \
# 0                                                NaN                37
# 1                                                NaN                74
# 2  microgravity; tissue effects; immune system; c...                70
# 3  adipose-derived stem cell; microgravity cultur...                48
# 4                                                NaN                38
#
#                                             Abstract  Year  Publication_Type  \
# 0  After a 16-year hiatus, Russia has resumed its...  2014  research-article
# 1  Bone is a dynamically remodeled tissue that re...  2013  research-article
# 2  Microgravity, defined by minimal gravitational...  2025    review-article
# 3  Therapeutic effects of adult stem-cell transpl...  2021  research-article
# 4  The International Space Station (ISS) National...  2017  research-article
#
#                                                  URL
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...

# %% [markdown]
# # Change the bad columns

# %%
are_equal = dfr["PMC_ID"].equals(dfr2["PMC_ID"])
print(f"The columns PMC_ID are equal: {are_equal}")
# Out:
# The columns PMC_ID are equal: True

# %%
dfr.columns
# Out:
# Index(['PMC_ID', 'Title', 'Authors', 'Introduction', 'Development/Methods',
#        'Results', 'Discussion', 'References'],
#       dtype='object')

# %%
dfr2.columns
# Out:
# Index(['PMC_ID', 'Title', 'Authors', 'Keywords', 'References_Count',
#        'Abstract', 'Year', 'Publication_Type', 'URL'],
#       dtype='object')

# %%
# Change the bad columns
dfr[["Title", "Authors", "References"]] = dfr2[["Title", "Authors", "References_Count"]]
dfr = dfr.rename(columns={"References": "References_Count"})
dfr.head()
# Out:
#         PMC_ID                                              Title  \
# 0   PMC4136787  Mice in Bion-M 1 Space Mission: Training and S...
# 1   PMC3630201  Microgravity Induces Pelvic Bone Loss through ...
# 2  PMC11988870  Microgravity and Cellular Biology: Insights in...
# 3   PMC7998608  Selective Proliferation of Highly Functional A...
# 4   PMC5587110  Microgravity validation of a novel system for ...
#
#                                              Authors  \
# 0  Alexander Andreev-Andrievskiy; Anfisa Popova; ...
# 1  Elizabeth A. Blaber; Natalya Dvorochkin; Chial...
# 2  Nelson Adolfo López Garzón; María Virginia Pin...
# 3  Takanobu Mashiko; Koji Kanayama; Natsumi Saito...
# 4  Macarena Parra; Jimmy Jung; Travis D. Boone; L...
#
#                                         Introduction  \
# 0  After a 16-year hiatus, Russia resumed in 2013...
# 1  On Earth, at 1 g, mechanical loading of mammal...
# 2  Microgravity, a condition characterized by min...
# 3  Human adipose-derived stem cells (hASCs) are e...
# 4  The ISS National Laboratory is a unique resear...
#
#                                  Development/Methods  \
# 0  The study was approved by IACUC of MSU Institu...
# 1  All experimental animal procedures for STS-131...
# 2  A comprehensive literature review was conducte...
# 3  Human lipoaspirates were obtained from 12 heal...
# 4  In order to validate the system, a number of g...
#
#                                              Results  \
# 0  Living conditions for animals considered optim...
# 1  All flight and ground control mice were observ...
# 2                                                NaN
# 3  Cells were expanded for three passages before ...
# 4  In order to assess the functionality of PCR in...
#
#                                           Discussion  References_Count
# 0  Living conditions for animals considered optim...                37
# 1  In this study, we investigated cellular and mo...                74
# 2  Recent research demonstrates that microgravity...                70
# 3  Through novel advances in cell biology, adult ...                48
# 4  One of the major obstacles to space exploratio...                38

# %%
# Save the updated DataFrame
dfr.to_csv("articles_data_updated.csv", index=False, encoding='utf-8')

# %%
# Add other columns
dfr[["Keywords", "Abstract", "Year", "Publicaction_type", "URL"]] = dfr2[["Keywords", "Abstract", "Year", "Publication_Type", "URL"]]
dfr.head(10)
# Out:
#         PMC_ID                                              Title  \
# 0   PMC4136787  Mice in Bion-M 1 Space Mission: Training and S...
# 1   PMC3630201  Microgravity Induces Pelvic Bone Loss through ...
# 2  PMC11988870  Microgravity and Cellular Biology: Insights in...
# 3   PMC7998608  Selective Proliferation of Highly Functional A...
# 4   PMC5587110  Microgravity validation of a novel system for ...
# 5   PMC8396460  Spaceflight Modulates the Expression of Key Ox...
# 6   PMC5666799  Dose- and Ion-Dependent Effects in the Oxidati...
# 7   PMC5460236  From the bench to exploration medicine: NASA l...
# 8   PMC6222041  High-precision method for cyclic loading of sm...
# 9   PMC6813909                                        Effects of
#
#                                              Authors  \
# 0  Alexander Andreev-Andrievskiy; Anfisa Popova; ...
# 1  Elizabeth A. Blaber; Natalya Dvorochkin; Chial...
# 2  Nelson Adolfo López Garzón; María Virginia Pin...
# 3  Takanobu Mashiko; Koji Kanayama; Natsumi Saito...
# 4  Macarena Parra; Jimmy Jung; Travis D. Boone; L...
# 5  Akhilesh Kumar; Candice G. T. Tahimic; Eduardo...
# 6  Joshua S. Alwood; Luan H. Tran; Ann-Sofie Schr...
# 7  Joshua S. Alwood; April E. Ronca; Richard C. M...
# 8  Megan M. Pendleton; Saghi Sadoughi; Alfred Li;...
# 9  Megan M. Pendleton; Shannon R. Emerzian; Jenni...
#
#                                         Introduction  \
# 0  After a 16-year hiatus, Russia resumed in 2013...
# 1  On Earth, at 1 g, mechanical loading of mammal...
# 2  Microgravity, a condition characterized by min...
# 3  Human adipose-derived stem cells (hASCs) are e...
# 4  The ISS National Laboratory is a unique resear...
# 5  Responses to spaceflight include cardiovascula...
# 6  Structural degradation and oxidative stress fo...
# 7  With the International Space Station (ISS) ava...
# 8  A number of diseases, including osteoporosis (...
# 9  For a variety of clinical applications, bones ...
#
#                                  Development/Methods  \
# 0  The study was approved by IACUC of MSU Institu...
# 1  All experimental animal procedures for STS-131...
# 2  A comprehensive literature review was conducte...
# 3  Human lipoaspirates were obtained from 12 heal...
# 4  In order to validate the system, a number of g...
# 5  All animal procedures were conducted in accord...
# 6  Male C57BL/6J mice (Jackson Laboratories, Bar ...
# 7                                                NaN
# 8  We first present our new method in detail. The...
# 9  Forty-eight female, 20-week old (skeletally-ma...
#
#                                              Results  \
# 0  Living conditions for animals considered optim...
# 1  All flight and ground control mice were observ...
# 2                                                NaN
# 3  Cells were expanded for three passages before ...
# 4  In order to assess the functionality of PCR in...
# 5  Immediately after landing, all flight (FLT) an...
# 6  To evaluate the individual effects of radiatio...
# 7                                                NaN
# 8  Of all three methods tested, the new (K FEA ) ...
# 9  For monotonic compression testing, the vertebr...
#
#                                           Discussion  References_Count  \
# 0  Living conditions for animals considered optim...                37
# 1  In this study, we investigated cellular and mo...                74
# 2  Recent research demonstrates that microgravity...                70
# 3  Through novel advances in cell biology, adult ...                48
# 4  One of the major obstacles to space exploratio...                38
# 5  Our findings provide new insight into how the ...                76
# 6  Heavy-ion irradiation during space missions is...                57
# 7                                                NaN                87
# 8  Our new method for cyclic loading of small-ani...                36
# 9  These results demonstrate that the monotonic s...                 0
#
#                                             Keywords  \
# 0                                                NaN
# 1                                                NaN
# 2  microgravity; tissue effects; immune system; c...
# 3  adipose-derived stem cell; microgravity cultur...
# 4                                                NaN
# 5  spaceflight; microgravity; heart; gene express...
# 6  cancellous bone; osteoblast; ionizing radiatio...
# 7                                                NaN
# 8  Fatigue; Bone mechanics; Mouse; Vertebrae; Bon...
# 9  ionizing radiation; bone strength; fatigue; co...
#
#                                             Abstract  Year Publicaction_type  \
# 0  After a 16-year hiatus, Russia has resumed its...  2014  research-article
# 1  Bone is a dynamically remodeled tissue that re...  2013  research-article
# 2  Microgravity, defined by minimal gravitational...  2025    review-article
# 3  Therapeutic effects of adult stem-cell transpl...  2021  research-article
# 4  The International Space Station (ISS) National...  2017  research-article
# 5  Spaceflight causes cardiovascular changes due ...  2021  research-article
# 6  Space radiation may pose a risk to skeletal he...  2017  research-article
# 7  NASA’s Space Biology and Human Research Progra...  2017      brief-report
# 8  One potentially important bone quality charact...  2018  research-article
# 9  Bone can become brittle when exposed to ionizi...  2019  research-article
#
#                                                  URL
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 5  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8...
# 6  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 7  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 8  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 9  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...

# %%
# Guardar el abstract de la primera fila
with open('abstract.txt', 'w', encoding='utf-8') as archivo:
    archivo.write(dfr["Abstract"].iloc[0])

print("Abstract guardado en abstract.txt")
# Out:
# Abstract guardado en abstract.txt

# %%
# Guardar la lista de columnas en un archivo txt
with open('columnas_dataframe.txt', 'w', encoding='utf-8') as archivo:
    archivo.write("COLUMNAS DEL DATAFRAME\n")
    archivo.write("=" * 50 + "\n")
    for i, columna in enumerate(dfr.columns, 1):
        archivo.write(f"{i}. {columna}\n")
    archivo.write(f"\nTotal columnas: {len(dfr.columns)}\n")
    archivo.write(f"Total filas: {len(dfr)}\n")

# Guardar todos los datos de la primera fila en un archivo txt
with open('primera_fila_completa.txt', 'w', encoding='utf-8') as archivo:
    archivo.write("PRIMERA FILA - TODAS LAS COLUMNAS\n")
    archivo.write("=" * 60 + "\n")
    for columna in dfr.columns:
        valor = dfr[columna].iloc[0]
        archivo.write(f"{columna}: {valor}\n")

# Guardar el abstract de la primera fila
with open('abstract.txt', 'w', encoding='utf-8') as archivo:
    archivo.write(dfr["Abstract"].iloc[0])

print("Archivos guardados:")
print("✅ abstract.txt")
print("✅ columnas_dataframe.txt") 
print("✅ primera_fila_completa.txt")
# Out:
# Archivos guardados:
# ✅ abstract.txt
# ✅ columnas_dataframe.txt
# ✅ primera_fila_completa.txt
