# %%
import pandas as pd
import requests
import xml.etree.ElementTree as ET
from Bio import Entrez
import time
import re

# %%
import pandas as pd
import requests
import xml.etree.ElementTree as ET
from Bio import Entrez
import time
import re

# Configuración de Entrez (obligatorio)
Entrez.email = "atauchimamani@gmail.com"
Entrez.api_key = None  # Opcional: puedes obtener una API key de NCBI

def clean_text(text):
    """Limpia el texto de caracteres especiales y espacios extra"""
    if text:
        text = re.sub(r'\s+', ' ', text)  # Reemplaza múltiples espacios
        text = text.strip()
        return text
    return ""

def extract_conclusions_from_abstract(abstract_text):
    """
    Extrae secciones de conclusiones del abstract.
    Esta es una aproximación - puedes ajustar los patrones según necesites.
    """
    if not abstract_text:
        return ""
    
    abstract_lower = abstract_text.lower()
    conclusions = []
    
    # Patrones comunes para secciones de conclusiones en abstracts
    patterns = [
        r'conclusions?[:\s]+(.+?)(?=(background|methods|results|discussion|$))',
        r'conclusion[:\s]+(.+?)$',
        r'in conclusion[:\s]+(.+?)$',
        r'these results suggest[:\s]+(.+?)$',
        r'we conclude[:\s]+(.+?)$',
        r'taken together[:\s]+(.+?)$'
    ]
    
    for pattern in patterns:
        matches = re.findall(pattern, abstract_text, re.IGNORECASE | re.DOTALL)
        for match in matches:
            if isinstance(match, tuple):
                conclusion_text = match[0]
            else:
                conclusion_text = match
            conclusion_text = clean_text(conclusion_text)
            if conclusion_text and len(conclusion_text) > 20:  # Mínimo de caracteres
                conclusions.append(conclusion_text)
    
    if conclusions:
        return " | ".join(conclusions[:3])  # Máximo 3 conclusiones
    
    # Si no encuentra patrones específicos, intenta obtener el último párrafo
    paragraphs = [p.strip() for p in abstract_text.split('.') if p.strip()]
    if len(paragraphs) >= 2:
        last_paragraph = paragraphs[-1]
        if len(last_paragraph) > 30:  # Solo si tiene suficiente contenido
            return clean_text(last_paragraph)
    
    return ""

def make_entrez_request_with_retry(func, *args, max_retries=3, delay=5, **kwargs):
    """
    Ejecuta una función de Entrez con reintentos automáticos para errores HTTP
    """
    for attempt in range(max_retries):
        try:
            return func(*args, **kwargs)
        except Exception as e:
            error_str = str(e)
            print(f"Intento {attempt + 1}/{max_retries} falló: {error_str}")
            
            # Verificar si es un error HTTP que merece reintento
            if any(error_code in error_str for error_code in ['400', '500', '502', '503', '504', 'Timeout']):
                if attempt < max_retries - 1:
                    wait_time = delay * (2 ** attempt)  # Backoff exponencial
                    print(f"Reintentando en {wait_time} segundos...")
                    time.sleep(wait_time)
                    continue
            else:
                # Si no es un error HTTP reintentable, relanzar la excepción
                raise e
    
    # Si se agotaron los reintentos
    raise Exception(f"Fallo después de {max_retries} intentos")

def get_pubmed_references(pmcid):
    """Obtiene las referencias de un artículo usando PMCID"""
    try:
        # Buscar el PMID usando PMCID con reintentos
        handle = make_entrez_request_with_retry(Entrez.esearch, db="pmc", term=pmcid)
        record = Entrez.read(handle)
        handle.close()
        
        if not record["IdList"]:
            return []
        
        # Obtener detalles del artículo con reintentos
        handle = make_entrez_request_with_retry(Entrez.efetch, db="pmc", id=record["IdList"][0], retmode="xml")
        xml_content = handle.read()
        handle.close()
        
        # Parsear XML
        root = ET.fromstring(xml_content)
        
        references = []
        # Buscar elementos de referencia en el XML
        for ref in root.findall(".//ref"):
            citation_elements = []
            
            # Extraer diferentes partes de la referencia
            for element in ref.iter():
                if element.text and element.text.strip():
                    tag = element.tag.split('}')[-1] if '}' in element.tag else element.tag
                    if tag in ['article-title', 'source', 'year', 'volume', 'issue', 'fpage', 'lpage']:
                        citation_elements.append(element.text.strip())
            
            if citation_elements:
                reference_text = " ".join(citation_elements)
                references.append(clean_text(reference_text))
        
        return references[:20]  # Limitar a las primeras 20 referencias
    
    except Exception as e:
        print(f"Error obteniendo referencias para {pmcid}: {e}")
        return []

def get_article_details(pmcid):
    """Obtiene abstract y detalles del artículo con manejo de errores"""
    try:
        # Buscar en PubMed con reintentos
        handle = make_entrez_request_with_retry(Entrez.esearch, db="pubmed", term=f"{pmcid}[pmcid]")
        record = Entrez.read(handle)
        handle.close()
        
        if not record["IdList"]:
            print(f"No se encontró PMID para PMCID: {pmcid}")
            return None, None
        
        pmid = record["IdList"][0]
        
        # Obtener detalles del artículo con reintentos
        handle = make_entrez_request_with_retry(Entrez.efetch, db="pubmed", id=pmid, retmode="xml")
        xml_content = handle.read()
        handle.close()
        
        # Parsear XML
        root = ET.fromstring(xml_content)
        
        # Extraer abstract
        abstract = ""
        abstract_elements = root.findall(".//AbstractText")
        for elem in abstract_elements:
            if elem.text:
                abstract += elem.text + " "
        
        abstract = clean_text(abstract)
        
        # Extraer conclusiones del abstract
        conclusions = extract_conclusions_from_abstract(abstract)
        
        return abstract, conclusions
    
    except Exception as e:
        print(f"Error obteniendo detalles para {pmcid}: {e}")
        return None, None

def safe_process_article(pmcid, max_attempts=2):
    """
    Procesa un artículo de manera segura con múltiples intentos
    """
    for attempt in range(max_attempts):
        try:
            abstract, conclusions = get_article_details(pmcid)
            references = get_pubmed_references(pmcid)
            return abstract, conclusions, references
        except Exception as e:
            print(f"Intento {attempt + 1}/{max_attempts} falló para {pmcid}: {e}")
            if attempt < max_attempts - 1:
                wait_time = 10 * (attempt + 1)  # 10, 20 segundos
                print(f"Reintentando en {wait_time} segundos...")
                time.sleep(wait_time)
            else:
                print(f"Fallo definitivo para {pmcid} después de {max_attempts} intentos")
                return None, None, []

def main():
    # Leer el archivo CSV
    try:
        df = pd.read_csv('articles_with_pmcid.csv')
        
        # Verificar que existe la columna PMC_ID
        if 'PMC_ID' not in df.columns:
            print("Error: No se encuentra la columna 'PMC_ID' en el archivo CSV")
            return
        
        pmc_ids = df['PMC_ID'].dropna().unique()
        print(f"Procesando {len(pmc_ids)} PMC IDs únicos...")
        
        results = []
        failed_ids = []
        
        for i, pmcid in enumerate(pmc_ids):
            print(f"Procesando {i+1}/{len(pmc_ids)}: {pmcid}")
            
            try:
                # Obtener abstract, conclusiones y referencias de manera segura
                abstract, conclusions, references = safe_process_article(pmcid)
                
                # Limitar el número de referencias para el CSV
                max_references = 10
                for j, ref in enumerate(references[:max_references]):
                    results.append({
                        'PMC_ID': pmcid,
                        'Abstract': abstract if j == 0 else "",  # Solo poner abstract en la primera fila
                        'Conclusions': conclusions if j == 0 else "",  # Solo poner conclusiones en la primera fila
                        'Reference_Number': j + 1,
                        'Reference': ref
                    })
                
                # Si no hay referencias, agregar una fila con solo el abstract y conclusiones
                if not references:
                    results.append({
                        'PMC_ID': pmcid,
                        'Abstract': abstract,
                        'Conclusions': conclusions,
                        'Reference_Number': 0,
                        'Reference': "No references found"
                    })
                
                print(f"✓ {pmcid} procesado correctamente")
                
            except Exception as e:
                print(f"✗ Error crítico procesando {pmcid}: {e}")
                failed_ids.append(pmcid)
                # Agregar una fila de error para mantener el registro
                results.append({
                    'PMC_ID': pmcid,
                    'Abstract': f"ERROR: {str(e)}",
                    'Conclusions': "",
                    'Reference_Number': -1,
                    'Reference': "Failed to process"
                })
            
            # Pausa para ser respetuoso con el servidor
            time.sleep(1)
        
        # Crear DataFrame de resultados
        results_df = pd.DataFrame(results)
        
        # Guardar resultados
        results_df.to_csv('resultado3.csv', index=False, encoding='utf-8')
        print(f"Resultados guardados en resultado3.csv")
        print(f"Total de filas procesadas: {len(results_df)}")
        
        if failed_ids:
            print(f"IDs que fallaron: {failed_ids}")
            # Guardar también una lista de los que fallaron
            failed_df = pd.DataFrame({'Failed_PMC_IDs': failed_ids})
            failed_df.to_csv('failed_pmc_ids.csv', index=False)
            print("Lista de IDs fallados guardada en failed_pmc_ids.csv")
        
    except FileNotFoundError:
        print("Error: No se encuentra el archivo 'articles_with_pmcid.csv'")
    except Exception as e:
        print(f"Error general: {e}")

if __name__ == "__main__":
    main()
# Out:
# Procesando 572 PMC IDs únicos...
# Procesando 1/572: PMC4136787
# ✓ PMC4136787 procesado correctamente
# Procesando 2/572: PMC3630201
# ✓ PMC3630201 procesado correctamente
# Procesando 3/572: PMC11988870
# ✓ PMC11988870 procesado correctamente
# Procesando 4/572: PMC7998608
# ✓ PMC7998608 procesado correctamente
# Procesando 5/572: PMC5587110
# ✓ PMC5587110 procesado correctamente
# Procesando 6/572: PMC8396460
# ✓ PMC8396460 procesado correctamente
# Procesando 7/572: PMC5666799
# ✓ PMC5666799 procesado correctamente
# Procesando 8/572: PMC5460236
# ✓ PMC5460236 procesado correctamente
# Procesando 9/572: PMC6222041
# ✓ PMC6222041 procesado correctamente
# Procesando 10/572: PMC6813909
# ✓ PMC6813909 procesado correctamente
# Procesando 11/572: PMC4095884
# ✓ PMC4095884 procesado correctamente
# Procesando 12/572: PMC3040128
# ✓ PMC3040128 procesado correctamente
# Procesando 13/572: PMC3177255
# ✓ PMC3177255 procesado correctamente
# Procesando 14/572: PMC11500582
# ...

# %%
df3 = pd.read_csv("resultado3.csv")
df3.head()
# Out:
#        PMC_ID                                           Abstract  \
# 0  PMC4136787  After a 16-year hiatus, Russia has resumed its...
# 1  PMC4136787                                                NaN
# 2  PMC4136787                                                NaN
# 3  PMC4136787                                                NaN
# 4  PMC4136787                                                NaN
#
#                                          Conclusions  Reference_Number  \
# 0  that our training program was effective and th...                 1
# 1                                                NaN                 2
# 2                                                NaN                 3
# 3                                                NaN                 4
# 4                                                NaN                 5
#
#                                            Reference
# 0  2007 Animals in space Vestnik Rossijskoj Akade...
# ...

# %%
dfr2 = pd.read_csv("articles_data_updated.csv")
dfr2.head()
# Out:
#         PMC_ID                                              Title  \
# 0   PMC4136787  Mice in Bion-M 1 Space Mission: Training and S...
# 1   PMC3630201  Microgravity Induces Pelvic Bone Loss through ...
# 2  PMC11988870  Microgravity and Cellular Biology: Insights in...
# 3   PMC7998608  Selective Proliferation of Highly Functional A...
# 4   PMC5587110  Microgravity validation of a novel system for ...
#
#                                              Authors  \
# 0  Alexander Andreev-Andrievskiy; Anfisa Popova; ...
# 1  Elizabeth A. Blaber; Natalya Dvorochkin; Chial...
# 2  Nelson Adolfo López Garzón; María Virginia Pin...
# 3  Takanobu Mashiko; Koji Kanayama; Natsumi Saito...
# 4  Macarena Parra; Jimmy Jung; Travis D. Boone; L...
#
#                                         Introduction  \
# 0  After a 16-year hiatus, Russia resumed in 2013...
# 1  On Earth, at 1 g, mechanical loading of mammal...
# 2  Microgravity, a condition characterized by min...
# ...

# %%
dfr2["References"] = df3["Reference"]
dfr2.head()
# Out:
#         PMC_ID                                              Title  \
# 0   PMC4136787  Mice in Bion-M 1 Space Mission: Training and S...
# 1   PMC3630201  Microgravity Induces Pelvic Bone Loss through ...
# 2  PMC11988870  Microgravity and Cellular Biology: Insights in...
# 3   PMC7998608  Selective Proliferation of Highly Functional A...
# 4   PMC5587110  Microgravity validation of a novel system for ...
#
#                                              Authors  \
# 0  Alexander Andreev-Andrievskiy; Anfisa Popova; ...
# 1  Elizabeth A. Blaber; Natalya Dvorochkin; Chial...
# 2  Nelson Adolfo López Garzón; María Virginia Pin...
# 3  Takanobu Mashiko; Koji Kanayama; Natsumi Saito...
# 4  Macarena Parra; Jimmy Jung; Travis D. Boone; L...
#
#                                         Introduction  \
# 0  After a 16-year hiatus, Russia resumed in 2013...
# 1  On Earth, at 1 g, mechanical loading of mammal...
# 2  Microgravity, a condition characterized by min...
# ...

# %%
# Save the updated DataFrame
dfr2.to_csv("articles_data_updated.csv", index=False, encoding='utf-8')
